# %%
import sys
print(sys.version)
# Out:
# 3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 16:37:03) [MSC v.1929 64 bit (AMD64)]

# %%
# keras --> to build a neural network
# tensorflow

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.20.0

# %%
import numpy as np
from numpy import loadtxt

# %%
data = loadtxt('diabetesclean.csv', delimiter=',') # read the dataset using numpy loadtxt

# %%
data.shape
# Out:
# (768, 9)

# %%
x = data[:, 0:8]
y = data[:, 8]

# %%
# print first 2 rows
x[0:3]
# Out:
# array([[  6.   , 148.   ,  72.   ,  35.   ,   0.   ,  33.6  ,   0.627,
#          50.   ],
#        [  1.   ,  85.   ,  66.   ,  29.   ,   0.   ,  26.6  ,   0.351,
#          31.   ],
#        [  8.   , 183.   ,  64.   ,   0.   ,   0.   ,  23.3  ,   0.672,
#          32.   ]])

# %%
y[0:3]
# Out:
# array([1., 0., 1.])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (614, 8)
# (154, 8)
# (614,)
# (154,)

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential()

# %%
model.add(Dense(8, input_dim = 8, activation= 'relu'))     # Input Layer
model.add(Dense(8, activation= 'relu'))                    # Hidden Layer
model.add(Dense(1, activation= 'sigmoid'))                  # Output Layer

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs= 10, batch_size=32)
# Out:
# Epoch 1/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4430 - loss: 6.9994
# Epoch 2/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5489 - loss: 4.1561
# Epoch 3/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5684 - loss: 3.4315
# Epoch 4/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5700 - loss: 2.8327
# Epoch 5/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5570 - loss: 2.4498
# Epoch 6/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5472 - loss: 2.1571
# Epoch 7/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5651 - loss: 1.8632
# Epoch 8/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5700 - loss: 1.6482
# Epoch 9/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5554 - loss: 1.4775
# Epoch 10/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5570 - loss: 1.3722

# %%
_, acc = model.evaluate(x_test, y_test)
print(f"Accuracy score for test data is {acc}")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5390 - loss: 1.3027
# Accuracy score for test data is 0.5389610528945923
